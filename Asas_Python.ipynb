# %% [markdown]
# <a href="https://colab.research.google.com/github/azzaharon/DKB3263/blob/main/Asas_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Python!")
print("Selamat datang ke latihan Python")
# Out:
# Hello, Python!
# Selamat datang ke latihan Python

# %% [markdown]
# #Pengenalan

# %%
nama = "Ali"
umur = 20
tinggi = 1.7

print(nama)
print(umur)
print(tinggi)
# Out:
# Ali
# 20
# 1.7

# %% [markdown]
# #Pemboleh Ubah

# %%
nama = input("Masukkan nama anda: ")
print("Selamat datang", nama)
# Out:
# Masukkan nama anda: Azza
# Selamat datang Azza

# %%
umur = int(input("Masukkan umur anda: "))
print("Umur anda ialah", umur)
# Out:
# Masukkan umur anda: 19
# Umur anda ialah 19

# %% [markdown]
# # Menerima input
